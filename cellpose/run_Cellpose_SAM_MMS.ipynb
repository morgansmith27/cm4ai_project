# %% [markdown]
# ## Cellpose-SAM: superhuman generalization for cellular segmentation
#
# Marius Pachitariu, Michael Rariden, Carsen Stringer
#
# [paper](https://www.biorxiv.org/content/10.1101/2025.04.28.651001v1) | [code](https://github.com/MouseLand/cellpose)
#
# This notebook shows how to process your own 2D or 3D images, saved on Google Drive.
#
# This notebook is adapted from the notebook by Pradeep Rajasekhar, inspired by the [ZeroCostDL4Mic notebook series](https://github.com/HenriquesLab/ZeroCostDL4Mic/wiki).

# %% [markdown]
# ### Make sure you have GPU access enabled by going to Runtime -> Change Runtime Type -> Hardware accelerator and selecting GPU
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Mount your google drive
#
# Run this cell to connect your Google Drive to colab:
# * Click on the URL.
# * Sign in your Google Account.
#
# You will either have to:
# * copy the authorisation code and enter it into box below OR
# * in the new google colab, you can just click "Allow" and it should connect.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Then click on "Folder" icon on the Left, press the refresh button. Your Google Drive folder should now be available here as "gdrive".
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Click on the triangle icon and it will allow you to access whole drive. Navigate to the folder containing your images. Once you are there, click on the three dots on the right of the folder and select "Copy Path"
#
# ![image.png](data:image/png;base64,...)
#
# Copy and paste this path in the **dir** string below

# %% [markdown]
# ### Install Cellpose-SAM

# %%
# !pip install git+https://www.github.com/mouseland/cellpose.git
# Out:
# Collecting git+https://www.github.com/mouseland/cellpose.git
#   Cloning https://www.github.com/mouseland/cellpose.git to /tmp/pip-req-build-1h57odo4
#   Running command git clone --filter=blob:none --quiet https://www.github.com/mouseland/cellpose.git /tmp/pip-req-build-1h57odo4
#   warning: redirecting to https://github.com/mouseland/cellpose.git/
#   Resolved https://www.github.com/mouseland/cellpose.git to commit d95f58a6676362d4e625076e55cd73b47c3bae26
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.7.dev14+gd95f58a66) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.7.dev14+gd95f58a66) (1.16.1)
# Requirement already satisfied: natsort in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.7.dev14+gd95f58a66) (8.4.0)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.7.dev14+gd95f58a66) (2025.6.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.7.dev14+gd95f58a66) (4.67.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.7.dev14+gd95f58a66) (0.23.0+cu126)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from cellpose==4.0.7.dev14+gd95f58a66) (4.12.0.88)
# Collecting fastremap (from cellpose==4.0.7.dev14+gd95f58a66)
#   Downloading fastremap-1.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting imagecodecs (from cellpose==4.0.7.dev14+gd95f58a66)
#   Downloading imagecodecs-2025.8.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (20 kB)
# Collecting roifile (from cellpose==4.0.7.dev14+gd95f58a66)
#   Downloading roifile-2025.5.10-py3-none-any.whl.metadata (5.9 kB)
# Collecting fill-voids (from cellpose==4.0.7.dev14+gd95f58a66)
#   Downloading fill_voids-2.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.0 kB)
# Collecting segment_anything (from cellpose==4.0.7.dev14+gd95f58a66)
#   Downloading segment_anything-1.0-py3-none-any.whl.metadata (487 bytes)
# Requirement already satisfied: torch==2.8.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->cellpose==4.0.7.dev14+gd95f58a66) (2.8.0+cu126)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->cellpose==4.0.7.dev14+gd95f58a66) (11.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->cellpose==4.0.7.dev14+gd95f58a66) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->cellpose==4.0.7.dev14+gd95f58a66) (4.14.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->cellpose==4.0.7.dev14+gd95f58a66) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->cellpose==4.0.7.dev14+gd95f58a66) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->cellpose==4.0.7.dev14+gd95f58a66) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->cellpose==4.0.7.dev14+gd95f58a66) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->cellpose==4.0.7.dev14+gd95f58a66) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->cellpose==4.0.7.dev14+gd95f58a66) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->cellpose==4.0.7.dev14+gd95f58a66) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->cellpose==4.0.7.dev14+gd95f58a66) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->cellpose==4.0.7.dev14+gd95f58a66) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->cellpose==4.0.7.dev14+gd95f58a66) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->cellpose==4.0.7.dev14+gd95f58a66) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->cellpose==4.0.7.dev14+gd95f58a66) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->cellpose==4.0.7.dev14+gd95f58a66) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->cellpose==4.0.7.dev14+gd95f58a66) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->cellpose==4.0.7.dev14+gd95f58a66) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->cellpose==4.0.7.dev14+gd95f58a66) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->cellpose==4.0.7.dev14+gd95f58a66) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->cellpose==4.0.7.dev14+gd95f58a66) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->cellpose==4.0.7.dev14+gd95f58a66) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->torchvision->cellpose==4.0.7.dev14+gd95f58a66) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.8.0->torchvision->cellpose==4.0.7.dev14+gd95f58a66) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.8.0->torchvision->cellpose==4.0.7.dev14+gd95f58a66) (3.0.2)
# Downloading fastremap-1.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 98.4 MB/s eta 0:00:00
# Downloading fill_voids-2.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 81.0 MB/s eta 0:00:00
# Downloading imagecodecs-2025.8.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (26.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 57.0 MB/s eta 0:00:00
# Downloading roifile-2025.5.10-py3-none-any.whl (17 kB)
# Downloading segment_anything-1.0-py3-none-any.whl (36 kB)
# Building wheels for collected packages: cellpose
#   Building wheel for cellpose (setup.py) ... done
#   Created wheel for cellpose: filename=cellpose-4.0.7.dev14+gd95f58a66-py3-none-any.whl size=212496 sha256=2aa6650c28e2b6918a4c25b6597dd0e57a68cbeff83c870ef7a89ae5903034b0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-h09obchv/wheels/df/b6/31/a3013c44290eabb46f4c06d1efb19744124fcad2d59684ec5e
# Successfully built cellpose
# Installing collected packages: segment_anything, roifile, imagecodecs, fastremap, fill-voids, cellpose
# Successfully installed cellpose-4.0.7.dev14+gd95f58a66 fastremap-1.17.2 fill-voids-2.1.0 imagecodecs-2025.8.2 roifile-2025.5.10 segment_anything-1.0

# %% [markdown]
# Check GPU and instantiate model - will download weights.

# %%
# !unzip /content/data.zip
# Out:
# Archive:  /content/data.zip
# replace data/.DS_Store? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import numpy as np
from cellpose import models, core, io, plot
from pathlib import Path
from tqdm import trange
import matplotlib.pyplot as plt
from natsort import natsorted

io.logger_setup() # run this to get printing of progress

#Check if colab notebook instance has GPU access
if core.use_gpu()==False:
  raise ImportError("No GPU access, change your runtime")

model = models.CellposeModel(gpu=True)
# Out:
# creating new log file
# 2025-08-20 20:40:36,059 [INFO] WRITING LOG OUTPUT TO /root/.cellpose/run.log
# 2025-08-20 20:40:36,060 [INFO]
# cellpose version: 	4.0.7.dev14+gd95f58a66
# platform:       	linux
# python version: 	3.12.11
# torch version:  	2.8.0+cu126
# 2025-08-20 20:40:36,277 [INFO] ** TORCH CUDA version installed and working. **
# 2025-08-20 20:40:36,278 [INFO] ** TORCH CUDA version installed and working. **
# 2025-08-20 20:40:36,280 [INFO] >>>> using GPU (CUDA)
# 2025-08-20 20:40:38,964 [INFO] Downloading: "https://huggingface.co/mouseland/cellpose-sam/resolve/main/cpsam" to /root/.cellpose/models/cpsam
# 100%|██████████| 1.15G/1.15G [00:06<00:00, 204MB/s]

# %% [markdown]
# Input directory with your images:

# %%
# *** change to your google drive folder path ***
dir = "/content/data/blue"
dir = Path(dir)
if not dir.exists():
  raise FileNotFoundError("directory does not exist")

# *** change to your image extension ***
image_ext = ".jpg"

# list all files
files = natsorted([f for f in dir.glob("*"+image_ext) if "_masks" not in f.name and "_flows" not in f.name])

if(len(files)==0):
  raise FileNotFoundError("no image files found, did you specify the correct folder and extension?")
else:
  print(f"{len(files)} images in folder:")

for f in files:
  print(f.name)
# Out:
# 10 images in folder:
# B2AI_1_Paclitaxel_A1_R2_z01_blue.jpg
# B2AI_1_Paclitaxel_A1_R5_z01_blue.jpg
# B2AI_1_Paclitaxel_A1_R6_z01_blue.jpg
# B2AI_1_Paclitaxel_A2_R5_z01_blue.jpg
# B2AI_1_Paclitaxel_A2_R7_z01_blue.jpg
# B2AI_1_Paclitaxel_A2_R11_z01_blue.jpg
# B2AI_1_Paclitaxel_A2_R12_z01_blue.jpg
# B2AI_1_Paclitaxel_A2_R14_z01_blue.jpg
# B2AI_1_Paclitaxel_A2_R17_z01_blue.jpg
# B2AI_1_Paclitaxel_A2_R18_z01_blue.jpg

# %% [markdown]
# ## Run Cellpose-SAM on one image in folder
#
# Here are some of the parameters you can change:
#
# * ***flow_threshold*** is  the  maximum  allowed  error  of  the  flows  for  each  mask.   The  default  is 0.4.
#     *  **Increase** this threshold if cellpose is not returning as many masks as you’d expect (or turn off completely with 0.0)
#     *   **Decrease** this threshold if cellpose is returning too many ill-shaped masks.
#
# * ***cellprob_threshold*** determines proability that a detected object is a cell.   The  default  is 0.0.
#     *   **Decrease** this threshold if cellpose is not returning as many masks as you’d expect or if masks are too small
#     *   **Increase** this threshold if cellpose is returning too many masks esp from dull/dim areas.
#
# * ***tile_norm_blocksize*** determines the size of blocks used for normalizing the image. The default is 0, which means the entire image is normalized together.
#   You may want to change this to 100-200 pixels if you have very inhomogeneous brightness across your image.

# %%
img = io.imread(files[0])

print(f'your image has shape: {img.shape}. Assuming channel dimension is last with {img.shape[-1]} channels')
# Out:
# your image has shape: (2048, 2048, 3). Assuming channel dimension is last with 3 channels

# %% [markdown]
# ### Channel Selection:
#
# - Use the dropdowns below to select the _zero-indexed_ channels of your image to segment. The order does not matter. Remember to rerun the cell after you edit the dropdowns.
#
# - If you have a histological image taken in brightfield, you don't need to adjust the channels.
#
# - If you have a fluroescent image with multiple stains, you should choose one channel with a cytoplasm/membrane stain, one channel with a nuclear stain, and set the third channel to `None`. Choosing multiple channels may produce segmentaiton of all the structures in the image. If you have retrained the model on your data with a thrid stain (described below), you can run segmentation with all channels.

# %%
first_channel = '0' # @param ['None', 0, 1, 2, 3, 4, 5]
second_channel = '1' # @param ['None', 0, 1, 2, 3, 4, 5]
third_channel = '2' # @param ['None', 0, 1, 2, 3, 4, 5]

# %%
selected_channels = []
for i, c in enumerate([first_channel, second_channel, third_channel]):
  if c == 'None':
    continue
  if int(c) > img.shape[-1]:
    assert False, 'invalid channel index, must have index greater or equal to the number of channels'
  if c != 'None':
    selected_channels.append(int(c))



img_selected_channels = np.zeros_like(img)
img_selected_channels[:, :, :len(selected_channels)] = img[:, :, selected_channels]


flow_threshold = 0.4
cellprob_threshold = 0.0
tile_norm_blocksize = 0

masks, flows, styles = model.eval(img_selected_channels, batch_size=32, flow_threshold=flow_threshold, cellprob_threshold=cellprob_threshold,
                                  normalize={"tile_norm_blocksize": tile_norm_blocksize})

fig = plt.figure(figsize=(12,5))
plot.show_segmentation(fig, img_selected_channels, masks, flows[0])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Run Cellpose-SAM on folder of images
#
# if you have many large images, you may want to run them as a loop over images

# %%
masks_ext = ".png" if image_ext == ".png" else ".tif"
for i in trange(len(files)):
    f = files[i]
    img = io.imread(f)
    masks, flows, styles = model.eval(img, batch_size=32, flow_threshold=flow_threshold, cellprob_threshold=cellprob_threshold,
                                  normalize={"tile_norm_blocksize": tile_norm_blocksize})
    io.imsave(dir / (f.stem + "_masks" + masks_ext), masks)
# Out:
# 100%|██████████| 10/10 [06:14<00:00, 37.40s/it]

# %% [markdown]
# if you have small images, you may want to load all of them first and then run, so that they can be batched together on the GPU

# %%
print("loading images")
imgs = [io.imread(files[i]) for i in trange(len(files))]

print("running cellpose-SAM")
masks, flows, styles = model.eval(imgs, batch_size=32, flow_threshold=flow_threshold, cellprob_threshold=cellprob_threshold,
                                  normalize={"tile_norm_blocksize": tile_norm_blocksize})

print("saving masks")
for i in trange(len(files)):
    f = files[i]
    io.imsave(dir / (f.stem + "_masks" + masks_ext), masks[i])
# Out:
# loading images
# 100%|██████████| 10/10 [00:00<00:00, 51.87it/s]
# running cellpose-SAM
# 2025-08-20 20:52:40,853 [INFO] 0%|          | 0/10 [00:00<?, ?it/s]
# 2025-08-20 20:53:22,219 [INFO] 10%|#         | 1/10 [00:41<06:12, 41.36s/it]
# 2025-08-20 20:53:58,811 [INFO] 20%|##        | 2/10 [01:17<05:08, 38.56s/it]
# 2025-08-20 20:54:36,802 [INFO] 30%|###       | 3/10 [01:55<04:28, 38.30s/it]
# 2025-08-20 20:55:13,840 [INFO] 40%|####      | 4/10 [02:32<03:46, 37.80s/it]
# 2025-08-20 20:55:50,582 [INFO] 50%|#####     | 5/10 [03:09<03:07, 37.42s/it]
# 2025-08-20 20:56:27,538 [INFO] 60%|######    | 6/10 [03:46<02:29, 37.26s/it]
# 2025-08-20 20:57:04,292 [INFO] 70%|#######   | 7/10 [04:23<01:51, 37.10s/it]
# 2025-08-20 20:57:41,008 [INFO] 80%|########  | 8/10 [05:00<01:13, 36.97s/it]
# 2025-08-20 20:58:17,767 [INFO] 90%|######### | 9/10 [05:36<00:36, 36.91s/it]
# 2025-08-20 20:58:54,622 [INFO] 100%|##########| 10/10 [06:13<00:00, 36.89s/it]
# 2025-08-20 20:58:54,622 [INFO] 100%|##########| 10/10 [06:13<00:00, 37.38s/it]
# saving masks
# 100%|██████████| 10/10 [00:00<00:00, 48.89it/s]

# %% [markdown]
# to save your masks for ImageJ, run the following code:
# -Edited by MMS
# ---

# %%
from pathlib import Path
from cellpose import io
from tqdm import trange

output_dir = Path("/content/cellpose_results/blue")
output_dir.mkdir(parents=True, exist_ok=True)

for i in trange(len(files)):
    f = files[i]

    # use your existing masks array from segmentation
    mask_array = masks[i]

    # save the mask image
    mask_path = output_dir / (f.stem + "_masks" + masks_ext)
    io.imsave(mask_path, mask_array)

    # optionally save ROIs
    io.save_rois(mask_array, mask_path)
# Out:
# 100%|██████████| 10/10 [00:07<00:00,  1.39it/s]

# %% [markdown]
# I wanted to save this instead so that the setup is ready for the cropping pipeline

# %%
from pathlib import Path
from cellpose import io
from tqdm import trange

# --- Define output folder ---
main_output = Path("/content/cellpose_results2")
sub_output = main_output / "blue"
sub_output.mkdir(parents=True, exist_ok=True)  # create folder if it doesn't exist

# --- Save existing masks ---
masks_ext = ".png" if image_ext == ".png" else ".tif"

for i in trange(len(files)):
    f = files[i]
    # assume masks is a list or array of masks in the same order as files
    io.imsave(sub_output / (f.stem + "_masks" + masks_ext), masks[i])

print("All masks saved to", sub_output)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 25.91it/s]
# All masks saved to /content/cellpose_results2/blue

# %%
from pathlib import Path
from tifffile import imread
from PIL import Image
import numpy as np

mask_folder = Path("/content/cellpose_results2/blue")
png_folder = mask_folder / "png"
png_folder.mkdir(exist_ok=True)

for mask_file in mask_folder.glob("*_masks*.tif"):  # or "*.tif" if all are TIFFs
    mask = imread(mask_file)

    # normalize to 0-255 for 8-bit PNG
    mask = mask.astype(np.float32)
    mask = 255 * (mask - mask.min()) / (mask.max() - mask.min())
    mask = mask.astype(np.uint8)

    Image.fromarray(mask).save(png_folder / (mask_file.stem + ".png"))

print("Masks converted to PNGs!")
# Out:
# Masks converted to PNGs!

# %%
#Now for the other colors. I'll start with red

# %%
dir = "/content/data/red"
dir = Path(dir)
if not dir.exists():
  raise FileNotFoundError("directory does not exist")

# *** change to your image extension ***
image_ext = ".jpg"

# list all files
files = natsorted([f for f in dir.glob("*"+image_ext) if "_masks" not in f.name and "_flows" not in f.name])

if(len(files)==0):
  raise FileNotFoundError("no image files found, did you specify the correct folder and extension?")
else:
  print(f"{len(files)} images in folder:")

for f in files:
  print(f.name)
# Out:
# 10 images in folder:
# B2AI_1_Paclitaxel_A1_R2_z01_red.jpg
# B2AI_1_Paclitaxel_A1_R5_z01_red.jpg
# B2AI_1_Paclitaxel_A1_R6_z01_red.jpg
# B2AI_1_Paclitaxel_A2_R5_z01_red.jpg
# B2AI_1_Paclitaxel_A2_R7_z01_red.jpg
# B2AI_1_Paclitaxel_A2_R11_z01_red.jpg
# B2AI_1_Paclitaxel_A2_R12_z01_red.jpg
# B2AI_1_Paclitaxel_A2_R14_z01_red.jpg
# B2AI_1_Paclitaxel_A2_R17_z01_red.jpg
# B2AI_1_Paclitaxel_A2_R18_z01_red.jpg

# %%
img = io.imread(files[0])

print(f'your image has shape: {img.shape}. Assuming channel dimension is last with {img.shape[-1]} channels')
# Out:
# your image has shape: (2048, 2048, 3). Assuming channel dimension is last with 3 channels

# %%
first_channel = '0' # @param ['None', 0, 1, 2, 3, 4, 5]
second_channel = '1' # @param ['None', 0, 1, 2, 3, 4, 5]
third_channel = '2' # @param ['None', 0, 1, 2, 3, 4, 5]

# %%
flow_threshold = 0.4
cellprob_threshold = 0.0
tile_norm_blocksize = 0

masks_ext = ".png" if image_ext == ".png" else ".tif"
for i in trange(len(files)):
    f = files[i]
    img = io.imread(f)
    masks, flows, styles = model.eval(img, batch_size=32, flow_threshold=flow_threshold, cellprob_threshold=cellprob_threshold,
                                  normalize={"tile_norm_blocksize": tile_norm_blocksize})
    io.imsave(dir / (f.stem + "_masks" + masks_ext), masks)
# Out:
# 100%|██████████| 10/10 [06:09<00:00, 36.98s/it]

# %%
print("loading images")
imgs = [io.imread(files[i]) for i in trange(len(files))]

print("running cellpose-SAM")
masks, flows, styles = model.eval(imgs, batch_size=32, flow_threshold=flow_threshold, cellprob_threshold=cellprob_threshold,
                                  normalize={"tile_norm_blocksize": tile_norm_blocksize})

print("saving masks")
for i in trange(len(files)):
    f = files[i]
    io.imsave(dir / (f.stem + "_masks" + masks_ext), masks[i])
# Out:
# loading images
# 100%|██████████| 10/10 [00:00<00:00, 55.03it/s]
# running cellpose-SAM
# 2025-08-20 21:29:38,028 [INFO] 0%|          | 0/10 [00:00<?, ?it/s]
# 2025-08-20 21:30:14,923 [INFO] 10%|#         | 1/10 [00:36<05:32, 36.89s/it]
# 2025-08-20 21:30:51,850 [INFO] 20%|##        | 2/10 [01:13<04:55, 36.91s/it]
# 2025-08-20 21:31:28,670 [INFO] 30%|###       | 3/10 [01:50<04:18, 36.87s/it]
# 2025-08-20 21:32:05,558 [INFO] 40%|####      | 4/10 [02:27<03:41, 36.88s/it]
# 2025-08-20 21:32:42,411 [INFO] 50%|#####     | 5/10 [03:04<03:04, 36.87s/it]
# 2025-08-20 21:33:19,421 [INFO] 60%|######    | 6/10 [03:41<02:27, 36.92s/it]
# 2025-08-20 21:33:56,236 [INFO] 70%|#######   | 7/10 [04:18<01:50, 36.88s/it]
# 2025-08-20 21:34:33,052 [INFO] 80%|########  | 8/10 [04:55<01:13, 36.86s/it]
# 2025-08-20 21:35:09,787 [INFO] 90%|######### | 9/10 [05:31<00:36, 36.82s/it]
# 2025-08-20 21:35:46,982 [INFO] 100%|##########| 10/10 [06:08<00:00, 36.94s/it]
# 2025-08-20 21:35:46,983 [INFO] 100%|##########| 10/10 [06:08<00:00, 36.90s/it]
# saving masks
# 100%|██████████| 10/10 [00:00<00:00, 51.54it/s]

# %%
from pathlib import Path
from cellpose import io
from tqdm import trange

output_dir = Path("/content/cellpose_results2/red")
output_dir.mkdir(parents=True, exist_ok=True)

for i in trange(len(files)):
    f = files[i]

    # use your existing masks array from segmentation
    mask_array = masks[i]

    # save the mask image
    mask_path = output_dir / (f.stem + "_masks" + masks_ext)
    io.imsave(mask_path, mask_array)

    # optionally save ROIs
    io.save_rois(mask_array, mask_path)
# Out:
# 100%|██████████| 10/10 [00:03<00:00,  3.08it/s]

# %%
from pathlib import Path
from tifffile import imread
from PIL import Image
import numpy as np

mask_folder = Path("/content/cellpose_results2/red")
png_folder = mask_folder / "png"
png_folder.mkdir(exist_ok=True)

for mask_file in mask_folder.glob("*_masks*.tif"):  # or "*.tif" if all are TIFFs
    mask = imread(mask_file)

    # normalize to 0-255 for 8-bit PNG
    mask = mask.astype(np.float32)
    mask = 255 * (mask - mask.min()) / (mask.max() - mask.min())
    mask = mask.astype(np.uint8)

    Image.fromarray(mask).save(png_folder / (mask_file.stem + ".png"))

print("Masks converted to PNGs!")
# Out:
# Masks converted to PNGs!

# %%
#Finally, we'll finish with yellow

# %%
dir = "/content/data/yellow"
dir = Path(dir)
if not dir.exists():
  raise FileNotFoundError("directory does not exist")

# *** change to your image extension ***
image_ext = ".jpg"

# list all files
files = natsorted([f for f in dir.glob("*"+image_ext) if "_masks" not in f.name and "_flows" not in f.name])

if(len(files)==0):
  raise FileNotFoundError("no image files found, did you specify the correct folder and extension?")
else:
  print(f"{len(files)} images in folder:")

for f in files:
  print(f.name)
# Out:
# 10 images in folder:
# B2AI_1_Paclitaxel_A1_R2_z01_yellow.jpg
# B2AI_1_Paclitaxel_A1_R5_z01_yellow.jpg
# B2AI_1_Paclitaxel_A1_R6_z01_yellow.jpg
# B2AI_1_Paclitaxel_A2_R5_z01_yellow.jpg
# B2AI_1_Paclitaxel_A2_R7_z01_yellow.jpg
# B2AI_1_Paclitaxel_A2_R11_z01_yellow.jpg
# B2AI_1_Paclitaxel_A2_R12_z01_yellow.jpg
# B2AI_1_Paclitaxel_A2_R14_z01_yellow.jpg
# B2AI_1_Paclitaxel_A2_R17_z01_yellow.jpg
# B2AI_1_Paclitaxel_A2_R18_z01_yellow.jpg

# %%
img = io.imread(files[0])

print(f'your image has shape: {img.shape}. Assuming channel dimension is last with {img.shape[-1]} channels')
# Out:
# your image has shape: (2048, 2048, 3). Assuming channel dimension is last with 3 channels

# %%
first_channel = '0' # @param ['None', 0, 1, 2, 3, 4, 5]
second_channel = '1' # @param ['None', 0, 1, 2, 3, 4, 5]
third_channel = '2' # @param ['None', 0, 1, 2, 3, 4, 5]

# %%
flow_threshold = 0.4
cellprob_threshold = 0.0
tile_norm_blocksize = 0

masks_ext = ".png" if image_ext == ".png" else ".tif"
for i in trange(len(files)):
    f = files[i]
    img = io.imread(f)
    masks, flows, styles = model.eval(img, batch_size=32, flow_threshold=flow_threshold, cellprob_threshold=cellprob_threshold,
                                  normalize={"tile_norm_blocksize": tile_norm_blocksize})
    io.imsave(dir / (f.stem + "_masks" + masks_ext), masks)
# Out:
# 100%|██████████| 10/10 [06:22<00:00, 38.29s/it]

# %%
print("loading images")
imgs = [io.imread(files[i]) for i in trange(len(files))]

print("running cellpose-SAM")
masks, flows, styles = model.eval(imgs, batch_size=32, flow_threshold=flow_threshold, cellprob_threshold=cellprob_threshold,
                                  normalize={"tile_norm_blocksize": tile_norm_blocksize})

print("saving masks")
for i in trange(len(files)):
    f = files[i]
    io.imsave(dir / (f.stem + "_masks" + masks_ext), masks[i])
# Out:
# loading images
# 100%|██████████| 10/10 [00:00<00:00, 47.95it/s]
# running cellpose-SAM
# 2025-08-20 21:43:44,837 [INFO] 0%|          | 0/10 [00:00<?, ?it/s]
# 2025-08-20 21:44:24,957 [INFO] 10%|#         | 1/10 [00:40<06:01, 40.12s/it]
# 2025-08-20 21:45:03,398 [INFO] 20%|##        | 2/10 [01:18<05:13, 39.13s/it]
# 2025-08-20 21:45:43,285 [INFO] 30%|###       | 3/10 [01:58<04:36, 39.48s/it]
# 2025-08-20 21:46:21,359 [INFO] 40%|####      | 4/10 [02:36<03:53, 38.92s/it]
# 2025-08-20 21:46:58,794 [INFO] 50%|#####     | 5/10 [03:13<03:11, 38.39s/it]
# 2025-08-20 21:47:36,513 [INFO] 60%|######    | 6/10 [03:51<02:32, 38.16s/it]
# 2025-08-20 21:48:14,179 [INFO] 70%|#######   | 7/10 [04:29<01:53, 38.00s/it]
# 2025-08-20 21:48:51,407 [INFO] 80%|########  | 8/10 [05:06<01:15, 37.75s/it]
# 2025-08-20 21:49:28,573 [INFO] 90%|######### | 9/10 [05:43<00:37, 37.57s/it]
# 2025-08-20 21:50:06,927 [INFO] 100%|##########| 10/10 [06:22<00:00, 37.81s/it]
# 2025-08-20 21:50:06,928 [INFO] 100%|##########| 10/10 [06:22<00:00, 38.21s/it]
# saving masks
# 100%|██████████| 10/10 [00:00<00:00, 27.29it/s]

# %%
from pathlib import Path
from cellpose import io
from tqdm import trange

output_dir = Path("/content/cellpose_results2/yellow")
output_dir.mkdir(parents=True, exist_ok=True)

for i in trange(len(files)):
    f = files[i]

    # use your existing masks array from segmentation
    mask_array = masks[i]

    # save the mask image
    mask_path = output_dir / (f.stem + "_masks" + masks_ext)
    io.imsave(mask_path, mask_array)

    # optionally save ROIs
    io.save_rois(mask_array, mask_path)
# Out:
# 100%|██████████| 10/10 [00:09<00:00,  1.09it/s]

# %%
from pathlib import Path
from tifffile import imread
from PIL import Image
import numpy as np

mask_folder = Path("/content/cellpose_results2/yellow")
png_folder = mask_folder / "png"
png_folder.mkdir(exist_ok=True)

for mask_file in mask_folder.glob("*_masks*.tif"):  # or "*.tif" if all are TIFFs
    mask = imread(mask_file)

    # normalize to 0-255 for 8-bit PNG
    mask = mask.astype(np.float32)
    mask = 255 * (mask - mask.min()) / (mask.max() - mask.min())
    mask = mask.astype(np.uint8)

    Image.fromarray(mask).save(png_folder / (mask_file.stem + ".png"))

print("Masks converted to PNGs!")
# Out:
# Masks converted to PNGs!

# %%
from google.colab import files
import shutil

# Path to the folder you want to download
folder_path = "/content/cellpose_results2"

# Create a zip archive
shutil.make_archive("/content/cellpose_results2", 'zip', folder_path)

# Download the zip
files.download("/content/cellpose_results2.zip")
